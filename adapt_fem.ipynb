# %% [markdown]
# ## 横軸 Force, 縦軸 Danger rate
# Forceを変えながらDanger rateの変化のEmodのばらつきの影響をsobol指数で可視化する．

# %%
import sys
sys.path.append("/home/toroi/Document/fem_study/application")

import uncertainpy as un
import chaospy as cp                       # To create distributions
import numpy as np                         # For the time array
from scipy.integrate import odeint         # To integrate our equation

from myfem import LoadInput, \
    ComputeGlobalStiffness, \
    ApplyFixedDBCs, \
    SolveDisplacement, \
    PostProcessing

# %%
path_inputfile = "/home/toroi/Document/fem_study/HW01/hw01_input03.txt"

# %%
load_input = LoadInput(path_inputfile)
basename_without_ext = os.path.splitext(os.path.basename(path_inputfile))[0]
(material_info, nodal_info, elements_info, bc_info, ef_info, fd_info) =\
    load_input.load_txt()

# %%
cgs = ComputeGlobalStiffness(
    elements_info,
    nodal_info,
    material_info,
    ndim=2
)

K = cgs.run()
print('{:-^50}'.format(' End : Compute Global Stiffness '))
print("")

print('{:-^50}'.format(' Start : Apply Fixed DBCs '))
afdbc = ApplyFixedDBCs(bc_info, ef_info, fd_info)
mod_K = afdbc.modify_stiffness_matrix(K)
external_force_vector = afdbc.modify_external_force_vector(
    nodal_info.shape[0])

# print("modified K shape => ", mod_K.shape)
# print(mod_K)
# print("modified ef shape => ", external_force_vector.shape)
# print(external_force_vector)
print('{:-^50}'.format(' End : Apply Fixed DBCs '))
print("")

print('{:-^50}'.format(' Start : Solve Displacement '))
solve_dis_force = SolveDisplacement(mod_K, external_force_vector)
displacements = solve_dis_force.recover_global_displacements()
print('{:-^50}'.format(' End : Solve Displacement '))
print("")

print('{:-^50}'.format(' Start : Post Processing '))
pp = PostProcessing(
    elements_info,
    nodal_info,
    material_info,
    ndim=2
)

print('{:-^50}'.format(' Compute reaction forces '))
reaction_forces = pp.reaction_forces(K, displacements)

print('{:-^50}'.format(' Compute internal forces '))
inter_forces = pp.internal_forces(displacements)

print('{:-^50}'.format(' Create output file '))
pp.output_result("./results/" + basename_without_ext,
                 K,
                 displacements,
                 visualize=True)

print('{:-^50}'.format(' End : Post Processing '))
# Out:
# --------- End : Compute Global Stiffness ---------
#
# ------------ Start : Apply Fixed DBCs ------------
# ------------- End : Apply Fixed DBCs -------------
#
# ----------- Start : Solve Displacement -----------
# ------------ End : Solve Displacement ------------
#
# ------------ Start : Post Processing -------------
# ------------ Compute reaction forces -------------
# ------------ Compute internal forces -------------
# --------------- Create output file ---------------
# ------------- End : Post Processing --------------

# %%
def uq_model_output_danger_rate(mat1_Emod, mat2_Emod):

    force_range = np.arange(-60, 60, 3)
    info = None

    cgs = ComputeGlobalStiffness(
        elements_info,
        nodal_info,
        material_info,
        ndim=2
    )

    # re-define Emod
    # print("Re-define Emod : ", Emod)
    material_info.loc[0, "Emod"] = mat1_Emod
    material_info.loc[1, "Emod"] = mat2_Emod

    danger_rates = []

    for force in force_range:
        # print("Force : ", force)
        ef_info.loc[0, "force"] = force

        K = cgs.run()

        afdbc = ApplyFixedDBCs(bc_info, ef_info, fd_info)
        mod_K = afdbc.modify_stiffness_matrix(K)
        external_force_vector = afdbc.modify_external_force_vector(
            nodal_info.shape[0])

        # print("modified K shape => ", mod_K.shape)
        # print(mod_K)
        # print("modified ef shape => ", external_force_vector.shape)
        # print(external_force_vector)
        solve_dis_force = SolveDisplacement(mod_K, external_force_vector)
        displacements = solve_dis_force.recover_global_displacements()
        pp = PostProcessing(
            elements_info,
            nodal_info,
            material_info,
            ndim=2
        )

        reaction_forces = pp.reaction_forces(K, displacements)

        inter_forces = pp.internal_forces(displacements)

        # modify 1d value for evaluation
        danger_rates.append(np.max(np.abs(inter_forces)))

    return force_range, danger_rates, info

# %%
Emod_dist1 = cp.Normal(700, 100)
Emod_dist2 = cp.Normal(20, 3)

param = {"mat1_Emod":Emod_dist1, "mat2_Emod":Emod_dist2}

model = un.Model(run=uq_model_output_danger_rate, labels=["Force", "Danger Rate"])

# %%
UQ = un.UncertaintyQuantification(model=model, parameters=param)

# %%
data = UQ.quantify(seed=10)
# Out:
# Re-define Emod :  Re-define Emod :  Re-define Emod : Re-define Emod : 353.9860247849597 412.745574558575
# 426.9795900078433
#  Force : Force :
#  387.254425441425
# -60Force :
# -60
# Running model:   0%|          | 0/12 [00:00<?, ?it/s]
#
# Force :  -57Force :
# -57
# Force :  -57
# Force :  -57
# Force :  -54
# Force :  -54
# Force :  -54Force :
#  -54
# Force :  -51
# Force :  -51
# Force :  -51Force :
#  -51
# Force :  -48
# Force :  -48
# Force :  -48
# Force :  -48
# Force :  -45
# Force :  -45
# Force :  -45
# Force :  -45
# Force :  -42
# Force :  -42
# Force :  -42
# Force :  -42
# Force :  -39
# Force :  -39
# Force :  -39
# Force :  -39
# Force :  -36
# Force :  -36
# Force :  -36
# Force :  -36
# Force :  -33
# Force :  -33
# Force :  -33
# Force :  -33
# Force :  -30Force :
#  -30
# Force :  -30
# Force :  -30
# Force :  -27
# Force :  -27
# Force :  -27
# Force :  -27
# Force :  -24
# Force :  -24
# Force :  -24
# Force :  -24
# Force :  -21
# Force :  -21
# Force :  Force : -21
#  -21
# Force :  -18
# Force :  -18
# Force :  -18
# Force :  -18
# Force :  -15
# Force :  -15
# Force :  -15
# Force :  -15
# Force :  -12
# Force :  -12
# Force :  -12
# Force :  -12
# Force :  -9
# Force :  -9
# Force :  -9
# Force :  -9
# Force :  Force : -6
#  -6
# Force :  -6
# Force :  -6
# Force :  -3
# Force :  -3
# Force :  -3
# Force :  -3
# Force :  0
# Force :  0
# Force :  0
# Force :  Force :  0
# 3
# Force :  3
# Force :  3
# Force :  3Force :
#  6
# Force :  6
# Force :  6
# Force :  6
# Force :  9
# Force :  9
# Force :  9
# Force :  9
# Force :  12
# Force :  12
# Force :  12
# Force :  12
# Force :  15
# Force :  15
# Force :  15
# Force :  15
# Force : Force :   18
# 18
# Force :  18
# Force :  18
# Force :  21
# Force : Force :  21
#  21
# Force :  24
# Force :  21
# Force :  24
# Force :  24
# Force :  24
# Force :  27
# Force :  27
# Force :  27
# Force :  27
# Force :  30
# Force :  30
# Force :  30
# Force :  30
# Force :  33
# Force :  33
# Force :  33
# Force :  33
# Force :  36
# Force :  36
# Force :  36
# Force :  36
# Force : Force :   3939
#
# Force :  39
# Force :  39
# Force :  42
# Force :  42
# Force :  42
# Force :  42
# Force :  45
# Force :  45
# Force :  45
# Force :  45
# Force :  48
# Force :  48
# Force :  48
# Force :  48
# Force :  Force :  5151
#
# Force :  51
# Force :  51
# Force :  54
# Force :  54
# Force :  54
# Force :  54
# Force :  57
# Force :  57
# Force :  57
# Force :  57
# Re-define Emod :  446.0139752150403
# Running model:   8%|▊         | 1/12 [00:56<10:23, 56.72s/it] Re-define Emod : -60
#  338.63517822589813
# Force :  -60
# Running model:  25%|██▌       | 3/12 [00:57<05:58, 39.79s/it]Re-define Emod :  406.29242738440684
# Force :  -60
# Running model:  33%|███▎      | 4/12 [00:57<03:44, 28.00s/it]Re-define Emod :  380.4489435554132
# Force :  -60
# Force :  -57
# Force :  -57
# Force :  -57
# Force :  -57
# Force :  -54
# Force :  -54
# Force :  -54
# Force :  -54
# Force :  -51
# Force :  -51
# Force :  -51
# Force :  -51
# Force :  -48
# Force :  -48
# Force :  -48
# Force :  -48
# Force :  -45
# Force :  -45
# Force :  -45
# Force :  -42
# Force :  -45
# Force :  -42
# Force :  -42
# Force :  -42Force :
#  -39
# Force :  -39
# Force :  -39
# Force :  -36
# Force :  -39
# Force :  -36
# Force :  -36
# Force :  -33Force :
#  -36
# Force :  -33
# Force :  -33
# Force :  -33Force :
# Force :  -30 -30
#
# Force :  -30
# Force :  -27
# Force :  -30
# Force :  -27
# Force :  -27
# Force :  -24
# Force :  -27
# Force :  -24
# Force :  -24
# Force :  -21
# Force :  -24
# Force :  -21
# Force :  -21
# Force :  -21
# Force :  -18
# Force :  -18
# Force :  -18
# Force :  -18
# Force :  -15
# Force :  -15
# Force : Force :   -15
# -15
# Force :  -12
# Force :  -12
# Force :  -12
# Force :  -12
# Force :  -9
# Force :  -9
# Force :  -9
# Force :  Force : -6
#  -9
# Force :  -6
# Force :  -6
# Force :  -3
# Force :  -6
# Force :  -3
# Force :  -3
# Force :  0
# Force :  -3
# Force :  0
# Force :  0
# Force :  3
# Force :  0
# Force :  3
# Force :  3
# Force :  6
# Force :  3
# Force :  6
# Force :  6
# Force :  9
# Force :  Force : 6
# 9
# Force :  9
# Force :  12
# Force :  9
# Force :  12
# Force :  12
# Force :  15
# Force :  12
# Force :  15
# Force :  15
# Force :  18
# Force :  15
# Force :  18
# Force :  18
# Force :  21
# Force :  18Force :
# Force :  21
# 21
# Force :  24
# Force :  24
# Force :  21
# Force :  24
# Force :  27
# Force :  Force :  2727
#
# Force :  24
# Force :  30Force :  30
#
# Force :  30
# Force :  27
# Force :  33
# Force :  33
# Force :  33
# Force :  30
# Force :  36
# Force :  36
# Force :  36
# Force :  33
# Force :  39Force :
# 39
# Force :  Force :  39
# 36
# Force :  42
# Force :  42
# Force :  42
# Force :  39
# Force :  45
# Force :  Force : 45
# 45
# Force :  42
# Force :  48
# Force :  48
# Force :  48
# Force :  45
# Force :  51
# Force :  51
# Force :  51
# Force :  48
# Force :  54
# Force :  54
# Force :  54
# Force :  51
# Force :  57
# Force :  57
# Force :  57
# Re-define Emod :  435.48586236075505
# Force :  -60
# Force :  54
# Running model:  42%|████▏     | 5/12 [01:55<04:17, 36.82s/it]Re-define Emod :  364.51413763924495
# Force :  -60
# Running model:  58%|█████▊    | 7/12 [01:55<02:09, 25.81s/it]Re-define Emod :  419.5510564445868
# Force :  -60
# Force :  57Force :
#  -57
# Force :  -57
# Force :  -57
# Running model:  67%|██████▋   | 8/12 [01:58<01:15, 18.85s/it]Re-define Emod :  393.70757261559316
# Force :  -60
# Force :  -54
# Force :  -54
# Force :  -54
# Force :  -57
# Force :  -51
# Force :  -51Force :
# -51
# Force :  -54
# Force :  -48
# Force :  -48
# Force :  -48
# Force :  -51
# Force :  -45
# Force :  Force : -45
# -45
# Force :  -48
# Force :  -42
# Force :  -42
# Force :  -42
# Force :  -45Force :
#  -39
# Force :  -39
# Force :  -39
# Force :  -42
# Force :  -36
# Force :  -36
# Force :  -36
# Force :  -33
# Force :  -39
# Force :  -33
# Force :  -33
# Force :  -30
# Force :  -36
# Force :  -30
# Force :  -30
# Force :  -27
# Force :  -33
# Force :  -27
# Force :  -27
# Force :  -24
# Force :  -30
# Force :  -24
# Force :  -24
# Force :  -27
# Force :  -21
# Force :  -21
# Force :  -21
# Force :  -24
# Force :  -18
# Force :  -18
# Force :  -21
# Force :  -18
# Force :  -15
# Force :  -15
# Force :  Force : -15
# -18
# Force :  -12
# Force :  -12
# Force :  -15
# Force :  -12
# Force :  -9
# Force : Force :  -9
#  -9Force :  -12
#
# Force :  -6
# Force :  -9
# Force :  Force : -6 -6
#
# Force :  -3
# Force :  -6
# Force :  -3
# Force :  -3
# Force :  0
# Force :  -3
# Force :  0
# Force :  0
# Force :  3
# Force :  3
# Force :  0
# Force :  3
# Force :  6
# Force :  6
# Force :  6
# Force :  3
# Force :  9
# Force :  9
# Force :  9
# Force :  6
# Force :  12
# Force :  12
# Force :  Force :  12
# 15
# Force :  9
# Force :  15
# Force :  18
# Force :  15
# Force :  18
# Force :  12
# Force :  21
# Force :  18
# Force :  15
# Force :  21
# Force :  24
# Force :  21
# Force :  18
# Force :  24
# Force :  27
# Force :  24
# Force :  27
# Force :  21
# Force :  30
# Force :  27
# Force :  30
# Force :  24
# Force :  30
# Force :  33
# Force :  33
# Force :  27
# Force : Force :   3636
#
# Force :  33
# Force :  30
# Force : Force :  36 39
# Force :
#  39
# Force :  33
# Force :  42
# Force :  39
# Force :  42
# Force :  36
# Force :  45
# Force :  42Force :
#  45
# Force :  39
# Force :  45
# Force :  48
# Force :  48
# Force :  42
# Force :  51
# Force : Force :   4851
#
# Force :  45
# Force :  51
# Force :  54
# Force :  54Force :
#  48
# Force :  54
# Force :  51
# Force :  57
# Force :  57
# Force :  57
# Force :  54
# Running model:  92%|█████████▏| 11/12 [02:55<00:14, 14.96s/it]Force :  57
# Running model: 100%|██████████| 12/12 [02:56<00:00, 14.70s/it]
# Calculating PC for each feature: 100%|██████████| 1/1 [00:00<00:00, 14.82it/s]
# Calculating statistics from PCE:   0%|          | 0/1 [00:00<?, ?it/s]Only 1 uncertain parameter. Sensitivities are not calculated
# Calculating statistics from PCE: 100%|██████████| 1/1 [00:00<00:00,  2.37it/s]
# Saving data as: data/uq_model_output_danger_rate.h5
# WARNING - All sobol_first_averages are missing. Unable to plot sobol_first_average_grid

# %%
material_info
# Out:
#    mid  mtype  rho   Emod     A
# 0  1.0    1.0  1.0  700.0  10.0
# 1  2.0    1.0  1.0   20.0  10.0
